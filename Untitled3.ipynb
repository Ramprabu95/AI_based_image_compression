# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramprabu95/AI_based_image_compression/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.nn.functional as F

# %%
device = torch.device('cuda')
# Definition of convolution layer
def conv(ni, nf, kernal_size=3, stride=1, padding=1, **kwargs):
    _conv = nn.Conv2d(ni, nf, kernel_size=kernal_size,stride=stride,padding=padding, **kwargs)
    nn.init.kaiming_normal_(_conv.weight)
    nn.init.zeros_(_conv.bias)
    return _conv

# Definition of a residual block
class ResBlock(nn.Module):
  def __init__(self, ni, nh=128):
    super(ResBlock,self).__init__()
    self.conv1 = conv(ni, nh)
    self.conv2 = conv(nh, ni)
  def forward(self, x):
    return x  + self.conv2(F.relu(self.conv1(x)))

# Definition of Relu block
relu = nn.ReLU()

# Definition of encoder
class Encoder(nn.Module):
  def __init__(self):
    super(Encoder, self).__init__()
    self.step1 = nn.Sequential(conv(3, 128, 8, 4, 2), relu,
                                   ResBlock(128), relu,
                                   conv(128, 256, 4, 2, 1), relu,
                                   ResBlock(256), relu,
                                   ResBlock(256), relu)
  def forward(self,x):
    x = self.step1(x)
    #print(x.shape)
    return(x)

# Function that does the binarizing action
class Binarizing_function(torch.autograd.Function):
  @staticmethod
  def forward(ctx, i):
    i = i*(i>0.25).float()
    p = (i<1).float()
    r = p*i
    q = (i>1).float()
    i = r+q
    #print(i)
    return i
  
  @staticmethod
  def backward(ctx,grad_output):
    return grad_output

def binary_value(x):
  return Binarizing_function.apply(x)

class Bin(nn.Module):
  def __init__(self,func):
    super(Bin,self).__init__()
    self.func = func

  def forward(self,x):
    return self.func(x)


# Quantizer of the importance map
class Quantizing(torch.autograd.Function):
  @staticmethod
  def forward(ctx, i):
    p_shape = i.shape
    p = i.clone().to(device)
    p = torch.reshape(p,(-1,)).to(device)
    #print(p.shape)
    L = 64
    for l in range(1,L):
      count = 0
      for q in p:
        #print('if condition',q, ((q<l/L) and (q>=(l+1)/L)))
        if((q<l/L) and (q>=(l-1)/L)):
          p[count] = l-1
        count = count +1
    p = torch.reshape(p,p_shape).to(device)
   # print('p is ',p.shape)
    return p
  @staticmethod
  def backward(ctx, grad_output):
    #N,Q,H,W = grad_output.shape
    return grad_output
  
def quantize_values(x):
  return Quantizing.apply(x)

class Masking(torch.autograd.Function):
  @staticmethod
  def forward(ctx,i):
    N,_,H,W = i.shape
    #print(i.shape)
    n = 256 # as per the paper
    L = 64 # as per the paper
    mask = torch.zeros(n,N*H*W).to(device)
    q_important = i
    q_important_flat = q_important.view(1, N*H*W)
    #print(q_important_flat.shape, q_important.shape)
    for index in range(n):
      count = 0
      for q in q_important_flat:
        mask[index,:] = torch.where(index <= (n/L)*q_important_flat[count],torch.Tensor([1]).to(device),torch.Tensor([0]).to(device))
      count = count +1
    mask = mask.view(N,n,H,W)
    #print(mask)
    return mask
  @staticmethod
  def backward(ctx, grad_output):
     N,Q,H,W = grad_output.shape
     #print(grad_output.shape)
     return grad_output
     
# function to generate mask
def generateMask(x):
  return Masking.apply(x)
  

# A decoder is to be defined which is a reverse of the encoder generated

class BitstoImage(torch.nn.Module):
  
  def __init__(self,blocksize):
    super(BitstoImage, self).__init__()
    self.blocksize = blocksize
  
  def forward(self,x):
    N,C,H,W = x.size()
    x = x.view(N, self.blocksize, self.blocksize,C // (self.blocksize ** 2), H, W)
    x = x.permute(0,3,4,1,5,2).contiguous()
    x = x.view(N, C // (self.blocksize ** 2), H*self.blocksize, W*self.blocksize)
    return x
# Definition of binarize 
class Encoder_full(nn.Module):
  def __init__(self,return_imp_map = False):
    super(Encoder_full,self).__init__()
    self.sig = nn.Sigmoid()
    # Layer that contains the binarizer
    self.step2 = nn.Sequential(conv(256,256,3,1,1),
                               nn.Sigmoid()                
                               )
    
    # Layer that contains the importance map 
    self.importance_map = nn.Sequential(conv(256,128),
                                        relu,
                                        conv(128,128),
                                        relu,
                                        conv(128,1),
                                        nn.Sigmoid())
    nn.init.xavier_normal_(self.step2[0].weight)
    nn.init.xavier_normal_(self.importance_map[4].weight)
  def forward(self,x,return_imp_map = False):
    if return_imp_map == True:
      x = self.importance_map(x)
      #print('t0',x.shape)
      return x
    else:
      x = self.step2(x)
      #print(x)
      return x

# Decoder design for rebulding the encoded data
class Decoder(nn.Module):
  def __init__(self):
    super(Decoder, self).__init__()
    # the convolution layers of a decoder is the reverse of the encoder
    self.decoder = nn.Sequential(nn.ConvTranspose2d(256,256,1,1,1), relu,
                                    ResBlock(256), relu,
                                    ResBlock(256), relu,
                                    nn.ConvTranspose2d(256,128,8,2,1), relu,
                                    ResBlock(128), relu,
                                    nn.ConvTranspose2d(128,3,8,4,2),nn.Sigmoid())

  def forward(self,x):
    #print(x.shape)
    return self.decoder(x)

encoder_step1 = Encoder().to(device)
encoder_step2 = Encoder_full(False).to(device)
print('********************Encoder Parameters***********************')
importance_map_full = Encoder_full(True).to(device)
print('********************Importance Map Parameters***********************')
print(importance_map_full.parameters)
decoder_full = Decoder().to(device)
print('********************Decoder Parameters***********************')
print(decoder_full.parameters)
# Out:
# ********************Encoder Parameters***********************
# ********************Importance Map Parameters***********************
# <bound method Module.parameters of Encoder_full(
#   (sig): Sigmoid()
#   (step2): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (importance_map): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Sigmoid()
#   )
# )>
# ********************Decoder Parameters***********************
# <bound method Module.parameters of Decoder(
#   (decoder): Sequential(
#     (0): ConvTranspose2d(256, 256, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): ResBlock(
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): ReLU()
#     (4): ResBlock(
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): ReLU()
#     (6): ConvTranspose2d(256, 128, kernel_size=(8, 8), stride=(2, 2), padding=(1, 1))
#     (7): ReLU()
#     (8): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (9): ReLU()
#     (10): ConvTranspose2d(128, 3, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#     (11): Sigmoid()
#   )
# )>

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras import *
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
from torch.autograd import Variable
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import random                                                                     
dir_root = '/content/drive/MyDrive/Colab Notebooks/'    
train_dir = os.path.join(dir_root, 'train (1)') 
plt.figure(figsize=(20,20))
for i in range(5):
    file = random.choice(os.listdir(train_dir))
    image_path= os.path.join(train_dir, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
from PIL import Image
TRAIN_TRANSFORMS_256 = transforms.Compose([transforms.RandomResizedCrop(256),
                                                   transforms.ToTensor()])
def load_image(path):
    return Image.open(path).convert("RGB")
def create_dataset(img_folder):
    count = 0
    img_data_array=[]
    for file in os.listdir(img_folder):
        count = count+ 1
        image_path= os.path.join(img_folder,  file)
        image= load_image(image_path)
        image_tensor = TRAIN_TRANSFORMS_256(image).to(device)
        img_data_array.append(image_tensor)
        if(count%100 ==0):
          print(count)
    return img_data_array
# extract the image array and class name
train_img_data =create_dataset(train_dir)
train_loader = torch.utils.data.DataLoader(train_img_data, batch_size=100, shuffle=True)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500

# %%
def loss_fn(input,output):
  rate_loss = nn.MSELoss()
  #dist_loss = torch.sum(imp_map)
  loss = torch.sqrt(rate_loss(input,output))
  return loss

# %%
import argparse
import torch
import torch.nn
from torch.utils.data import DataLoader
import os
from torchvision.utils import save_image

class full_layers(nn.Module):
  def __init__(self,imp_map_present = False):
        super(full_layers, self).__init__()
        self.encoder = Encoder()
        self.encoder_rest = Encoder_full()
        self.imp_map_gen = Encoder_full(True)
        self.decoder = Decoder()     
  def forward(self,x,imp_map_present = False):
    #print(x.shape)
    inter_result = self.encoder(x)
    #print(quantized_op)
    op1 = binary_value(self.encoder_rest(inter_result)).to(device)
    #print(op1.shape,op2.shape)
    if(imp_map_present == True):
      importance_map = self.imp_map_gen(inter_result, True)
      quantized_op = quantize_values(importance_map).to(device)
      masked_op = generateMask(quantized_op).to(device)
      op2 = masked_op.to(device)
      y = (op1*op2).to(device)
      return self.decoder(y), importance_map
    else:
      y = op1.to(device)
      #print(y)
          #print(y)
    return self.decoder(y)

fullnet = full_layers(False).to(device)
print(fullnet.parameters)
fullnet.train()
return_imp_map = False
for p in fullnet.imp_map_gen.parameters():
  p.requires_grad_ = False
optimizer = torch.optim.Adam(fullnet.parameters(), lr=0.0001)
running_loss = 0.0
trial = [[[]]]
for epoch in range(12):
  for i,data in enumerate(train_img_data, 0):
    inputs = data.unsqueeze(0).to(device)
    trial = inputs
    #print(inputs.shape)
    inputs = Variable(inputs)
    optimizer.zero_grad()
    for p in fullnet.imp_map_gen.parameters():
      p.requires_grad = False
      ##print (p)
    output = fullnet(inputs,False)
    output = output
    #print(output.shape, inputs.shape)
    loss = loss_fn(output, inputs)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    if i%100 == 99:
      print('[%5d epoch] loss: %.3f'% (epoch+1,running_loss/100))
      if(running_loss/100 < 0.06):
        optimizer = torch.optim.Adam(fullnet.parameters(), lr=0.00001)
      if(running_loss/100 < 0.05):
        optimizer = torch.optim.Adam(fullnet.parameters(), lr=0.000001)
      if(running_loss/100< 0.04):
        break
      running_loss = 0.0
print('Training completed')

print('Learnig Concolutional Networks for content-weighted image compression')
print('Step1 : Loading of the training data')

print('Step2 : Training of the encode created')
print('Step3 : Training of the importance map generator')
print('Step4 : Testing the compression')
PATH = './cifar_net.pth'
torch.save(fullnet.state_dict(), PATH)
# Out:
# <bound method Module.parameters of full_layers(
#   (encoder): Encoder(
#     (step1): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#       (1): ReLU()
#       (2): ResBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ReLU()
#       (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (5): ReLU()
#       (6): ResBlock(
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (7): ReLU()
#       (8): ResBlock(
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (9): ReLU()
#     )
#   )
#   (encoder_rest): Encoder_full(
#     (sig): Sigmoid()
#     (step2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Sigmoid()
#     )
#     (importance_map): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): Sigmoid()
#     )
#   )
#   (imp_map_gen): Encoder_full(
#     (sig): Sigmoid()
#     (step2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Sigmoid()
#     )
#     (importance_map): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): Sigmoid()
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): ResBlock(
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ReLU()
#       (4): ResBlock(
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (5): ReLU()
#       (6): ConvTranspose2d(256, 128, kernel_size=(8, 8), stride=(2, 2), padding=(1, 1))
#       (7): ReLU()
#       (8): ResBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (9): ReLU()
#       (10): ConvTranspose2d(128, 3, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#       (11): Sigmoid()
#     )
#   )
# )>
# [    1 epoch] loss: 0.247
# [    1 epoch] loss: 0.180
# [    1 epoch] loss: 0.159
# [    1 epoch] loss: 0.147
# [    1 epoch] loss: 0.117
# [    1 epoch] loss: 0.125
# [    1 epoch] loss: 0.121
# [    1 epoch] loss: 0.114
# [    1 epoch] loss: 0.114
# [    1 epoch] loss: 0.129
# [    1 epoch] loss: 0.118
# [    1 epoch] loss: 0.116
# [    1 epoch] loss: 0.107
# [    1 epoch] loss: 0.102
# [    1 epoch] loss: 0.104
# [    1 epoch] loss: 0.102
# [    1 epoch] loss: 0.109
# [    1 epoch] loss: 0.099
# [    1 epoch] loss: 0.102
# [    1 epoch] loss: 0.111
# [    1 epoch] loss: 0.088
# [    1 epoch] loss: 0.091
# [    1 epoch] loss: 0.097
# [    1 epoch] loss: 0.098
# [    1 epoch] loss: 0.103
# [    2 epoch] loss: 0.134
# [    2 epoch] loss: 0.093
# [    2 epoch] loss: 0.099
# [    2 epoch] loss: 0.090
# [    2 epoch] loss: 0.078
# [    2 epoch] loss: 0.088
# [    2 epoch] loss: 0.081
# [    2 epoch] loss: 0.084
# [    2 epoch] loss: 0.085
# [    2 epoch] loss: 0.095
# [    2 epoch] loss: 0.091
# [    2 epoch] loss: 0.103
# [    2 epoch] loss: 0.089
# [    2 epoch] loss: 0.076
# [    2 epoch] loss: 0.083
# [    2 epoch] loss: 0.078
# [    2 epoch] loss: 0.087
# [    2 epoch] loss: 0.075
# [    2 epoch] loss: 0.086
# [    2 epoch] loss: 0.089
# [    2 epoch] loss: 0.071
# [    2 epoch] loss: 0.078
# [    2 epoch] loss: 0.078
# [    2 epoch] loss: 0.071
# [    2 epoch] loss: 0.080
# [    3 epoch] loss: 0.108
# [    3 epoch] loss: 0.072
# [    3 epoch] loss: 0.077
# [    3 epoch] loss: 0.075
# [    3 epoch] loss: 0.064
# [    3 epoch] loss: 0.074
# [    3 epoch] loss: 0.067
# [    3 epoch] loss: 0.071
# [    3 epoch] loss: 0.069
# [    3 epoch] loss: 0.079
# [    3 epoch] loss: 0.074
# [    3 epoch] loss: 0.081
# [    3 epoch] loss: 0.070
# [    3 epoch] loss: 0.062
# [    3 epoch] loss: 0.068
# [    3 epoch] loss: 0.064
# [    3 epoch] loss: 0.071
# [    3 epoch] loss: 0.070
# [    3 epoch] loss: 0.080
# [    3 epoch] loss: 0.076
# [    3 epoch] loss: 0.064
# [    3 epoch] loss: 0.068
# [    3 epoch] loss: 0.069
# [    3 epoch] loss: 0.061
# [    3 epoch] loss: 0.072
# [    4 epoch] loss: 0.100
# [    4 epoch] loss: 0.068
# [    4 epoch] loss: 0.071
# [    4 epoch] loss: 0.068
# [    4 epoch] loss: 0.059
# [    4 epoch] loss: 0.065
# [    4 epoch] loss: 0.059
# [    4 epoch] loss: 0.060
# [    4 epoch] loss: 0.055
# [    4 epoch] loss: 0.066
# [    4 epoch] loss: 0.063
# [    4 epoch] loss: 0.062
# [    4 epoch] loss: 0.053
# [    4 epoch] loss: 0.053
# [    4 epoch] loss: 0.061
# [    4 epoch] loss: 0.055
# [    4 epoch] loss: 0.061
# [    4 epoch] loss: 0.054
# [    4 epoch] loss: 0.064
# [    4 epoch] loss: 0.060
# [    4 epoch] loss: 0.057
# [    4 epoch] loss: 0.060
# [    4 epoch] loss: 0.061
# [    4 epoch] loss: 0.051
# [    4 epoch] loss: 0.059
# [    5 epoch] loss: 0.084
# [    5 epoch] loss: 0.056
# [    5 epoch] loss: 0.065
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.053
# [    5 epoch] loss: 0.062
# [    5 epoch] loss: 0.056
# [    5 epoch] loss: 0.058
# [    5 epoch] loss: 0.053
# [    5 epoch] loss: 0.063
# [    5 epoch] loss: 0.061
# [    5 epoch] loss: 0.061
# [    5 epoch] loss: 0.051
# [    5 epoch] loss: 0.051
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.054
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.052
# [    5 epoch] loss: 0.062
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.055
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.059
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.057
# [    6 epoch] loss: 0.082
# [    6 epoch] loss: 0.055
# [    6 epoch] loss: 0.063
# [    6 epoch] loss: 0.057
# [    6 epoch] loss: 0.051
# [    6 epoch] loss: 0.061
# [    6 epoch] loss: 0.055
# [    6 epoch] loss: 0.057
# [    6 epoch] loss: 0.052
# [    6 epoch] loss: 0.062
# [    6 epoch] loss: 0.059
# [    6 epoch] loss: 0.058
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.057
# [    6 epoch] loss: 0.053
# [    6 epoch] loss: 0.058
# [    6 epoch] loss: 0.051
# [    6 epoch] loss: 0.061
# [    6 epoch] loss: 0.057
# [    6 epoch] loss: 0.054
# [    6 epoch] loss: 0.057
# [    6 epoch] loss: 0.058
# [    6 epoch] loss: 0.048
# [    6 epoch] loss: 0.056
# [    7 epoch] loss: 0.080
# [    7 epoch] loss: 0.054
# [    7 epoch] loss: 0.062
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.051
# [    7 epoch] loss: 0.060
# [    7 epoch] loss: 0.054
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.051
# [    7 epoch] loss: 0.061
# [    7 epoch] loss: 0.058
# [    7 epoch] loss: 0.058
# [    7 epoch] loss: 0.048
# [    7 epoch] loss: 0.048
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.052
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.050
# [    7 epoch] loss: 0.059
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.053
# [    7 epoch] loss: 0.056
# [    7 epoch] loss: 0.057
# [    7 epoch] loss: 0.047
# [    7 epoch] loss: 0.055
# [    8 epoch] loss: 0.079
# [    8 epoch] loss: 0.052
# [    8 epoch] loss: 0.061
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.050
# [    8 epoch] loss: 0.059
# [    8 epoch] loss: 0.053
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.050
# [    8 epoch] loss: 0.060
# [    8 epoch] loss: 0.057
# [    8 epoch] loss: 0.056
# [    8 epoch] loss: 0.047
# [    8 epoch] loss: 0.047
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.051
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.049
# [    8 epoch] loss: 0.059
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.052
# [    8 epoch] loss: 0.055
# [    8 epoch] loss: 0.056
# [    8 epoch] loss: 0.046
# [    8 epoch] loss: 0.054
# [    9 epoch] loss: 0.077
# [    9 epoch] loss: 0.051
# [    9 epoch] loss: 0.060
# [    9 epoch] loss: 0.055
# [    9 epoch] loss: 0.049
# [    9 epoch] loss: 0.058
# [    9 epoch] loss: 0.052
# [    9 epoch] loss: 0.054
# [    9 epoch] loss: 0.050
# [    9 epoch] loss: 0.059
# [    9 epoch] loss: 0.056
# [    9 epoch] loss: 0.055
# [    9 epoch] loss: 0.047
# [    9 epoch] loss: 0.047
# [    9 epoch] loss: 0.054
# [    9 epoch] loss: 0.050
# [    9 epoch] loss: 0.054
# [    9 epoch] loss: 0.048
# [    9 epoch] loss: 0.058
# [    9 epoch] loss: 0.054
# [    9 epoch] loss: 0.051
# [    9 epoch] loss: 0.055
# [    9 epoch] loss: 0.055
# [    9 epoch] loss: 0.046
# [    9 epoch] loss: 0.053
# [   10 epoch] loss: 0.076
# [   10 epoch] loss: 0.051
# [   10 epoch] loss: 0.059
# [   10 epoch] loss: 0.054
# [   10 epoch] loss: 0.048
# [   10 epoch] loss: 0.057
# [   10 epoch] loss: 0.051
# [   10 epoch] loss: 0.053
# [   10 epoch] loss: 0.049
# [   10 epoch] loss: 0.058
# [   10 epoch] loss: 0.055
# [   10 epoch] loss: 0.054
# [   10 epoch] loss: 0.046
# [   10 epoch] loss: 0.046
# [   10 epoch] loss: 0.053
# [   10 epoch] loss: 0.050
# [   10 epoch] loss: 0.053
# [   10 epoch] loss: 0.047
# [   10 epoch] loss: 0.057
# [   10 epoch] loss: 0.054
# [   10 epoch] loss: 0.051
# [   10 epoch] loss: 0.054
# [   10 epoch] loss: 0.054
# [   10 epoch] loss: 0.045
# [   10 epoch] loss: 0.052
# [   11 epoch] loss: 0.075
# [   11 epoch] loss: 0.050
# [   11 epoch] loss: 0.058
# [   11 epoch] loss: 0.053
# [   11 epoch] loss: 0.048
# [   11 epoch] loss: 0.057
# [   11 epoch] loss: 0.051
# [   11 epoch] loss: 0.053
# [   11 epoch] loss: 0.048
# [   11 epoch] loss: 0.057
# [   11 epoch] loss: 0.054
# [   11 epoch] loss: 0.054
# [   11 epoch] loss: 0.045
# [   11 epoch] loss: 0.045
# [   11 epoch] loss: 0.052
# [   11 epoch] loss: 0.049
# [   11 epoch] loss: 0.053
# [   11 epoch] loss: 0.047
# [   11 epoch] loss: 0.056
# [   11 epoch] loss: 0.052
# [   11 epoch] loss: 0.050
# [   11 epoch] loss: 0.053
# [   11 epoch] loss: 0.054
# [   11 epoch] loss: 0.044
# [   11 epoch] loss: 0.052
# [   12 epoch] loss: 0.074
# [   12 epoch] loss: 0.049
# [   12 epoch] loss: 0.057
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.047
# [   12 epoch] loss: 0.056
# [   12 epoch] loss: 0.050
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.048
# [   12 epoch] loss: 0.057
# [   12 epoch] loss: 0.053
# [   12 epoch] loss: 0.053
# [   12 epoch] loss: 0.045
# [   12 epoch] loss: 0.045
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.048
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.046
# [   12 epoch] loss: 0.056
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.050
# [   12 epoch] loss: 0.052
# [   12 epoch] loss: 0.053
# [   12 epoch] loss: 0.044
# [   12 epoch] loss: 0.051
# Training completed
# Learnig Concolutional Networks for content-weighted image compression
# Step1 : Loading of the training data
# Step2 : Training of the encode created
# Step3 : Training of the importance map generator
# Step4 : Testing the compression

# %%
fullnet1 = full_layers(True).to(device)
fullnet1.load_state_dict(torch.load(PATH))
optimizer = torch.optim.Adam(fullnet1.parameters(), lr=0.0001)
running_loss = 0.0
for p in fullnet1.imp_map_gen.parameters():
  p.requires_grad = False
for q in fullnet1.encoder.parameters():
  q.requires_grad = False
trial = [[[]]]
for epoch in range(7):
  for i,data in enumerate(train_img_data, 0):
    inputs = data.unsqueeze(0).to(device)
    trial = inputs
    #print(inputs.shape)
    inputs = Variable(inputs)
    optimizer.zero_grad()
    for p in fullnet1.imp_map_gen.parameters():
     p.requires_grad = False
    for q in fullnet1.encoder.parameters():
     q.requires_grad = False
    output = fullnet1(inputs,True)
    imp_map = output[1]
    output = output[0]
    #print(imp_map)
    #print(output.shape, inputs.shape)
    loss = loss_fn(output, inputs)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    if i%100 == 99:
      print('[%5d epoch] loss: %.3f'% (epoch+1,running_loss/100))
      #print(imp_map)
      if(running_loss/100 < 0.05):
        optimizer = torch.optim.Adam(fullnet1.parameters(), lr=0.00001)
        #print(imp_map)
      if(running_loss/100 < 0.04):
        optimizer = torch.optim.Adam(fullnet1.parameters(), lr=0.000001)
      if(running_loss/100 < 0.03):
        break
      running_loss = 0.0
# Out:
# [    1 epoch] loss: 0.070
# [    1 epoch] loss: 0.057
# [    1 epoch] loss: 0.064
# [    1 epoch] loss: 0.058
# [    1 epoch] loss: 0.052
# [    1 epoch] loss: 0.062
# [    1 epoch] loss: 0.057
# [    1 epoch] loss: 0.058
# [    1 epoch] loss: 0.055
# [    1 epoch] loss: 0.064
# [    1 epoch] loss: 0.061
# [    1 epoch] loss: 0.058
# [    1 epoch] loss: 0.053
# [    1 epoch] loss: 0.051
# [    1 epoch] loss: 0.058
# [    1 epoch] loss: 0.059
# [    1 epoch] loss: 0.058
# [    1 epoch] loss: 0.054
# [    1 epoch] loss: 0.063
# [    1 epoch] loss: 0.059
# [    1 epoch] loss: 0.053
# [    1 epoch] loss: 0.056
# [    1 epoch] loss: 0.057
# [    1 epoch] loss: 0.049
# [    1 epoch] loss: 0.057
# [    2 epoch] loss: 0.075
# [    2 epoch] loss: 0.050
# [    2 epoch] loss: 0.058
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.047
# [    2 epoch] loss: 0.056
# [    2 epoch] loss: 0.050
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.048
# [    2 epoch] loss: 0.056
# [    2 epoch] loss: 0.053
# [    2 epoch] loss: 0.053
# [    2 epoch] loss: 0.045
# [    2 epoch] loss: 0.045
# [    2 epoch] loss: 0.051
# [    2 epoch] loss: 0.048
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.046
# [    2 epoch] loss: 0.055
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.049
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.052
# [    2 epoch] loss: 0.043
# [    2 epoch] loss: 0.051
# [    3 epoch] loss: 0.072
# [    3 epoch] loss: 0.048
# [    3 epoch] loss: 0.056
# [    3 epoch] loss: 0.051
# [    3 epoch] loss: 0.046
# [    3 epoch] loss: 0.055
# [    3 epoch] loss: 0.049
# [    3 epoch] loss: 0.051
# [    3 epoch] loss: 0.047
# [    3 epoch] loss: 0.055
# [    3 epoch] loss: 0.052
# [    3 epoch] loss: 0.052
# [    3 epoch] loss: 0.044
# [    3 epoch] loss: 0.044
# [    3 epoch] loss: 0.050
# [    3 epoch] loss: 0.047
# [    3 epoch] loss: 0.051
# [    3 epoch] loss: 0.045
# [    3 epoch] loss: 0.054
# [    3 epoch] loss: 0.051
# [    3 epoch] loss: 0.048
# [    3 epoch] loss: 0.051
# [    3 epoch] loss: 0.052
# [    3 epoch] loss: 0.043
# [    3 epoch] loss: 0.050
# [    4 epoch] loss: 0.071
# [    4 epoch] loss: 0.048
# [    4 epoch] loss: 0.056
# [    4 epoch] loss: 0.050
# [    4 epoch] loss: 0.045
# [    4 epoch] loss: 0.054
# [    4 epoch] loss: 0.049
# [    4 epoch] loss: 0.050
# [    4 epoch] loss: 0.046
# [    4 epoch] loss: 0.055
# [    4 epoch] loss: 0.052
# [    4 epoch] loss: 0.051
# [    4 epoch] loss: 0.043
# [    4 epoch] loss: 0.043
# [    4 epoch] loss: 0.050
# [    4 epoch] loss: 0.047
# [    4 epoch] loss: 0.050
# [    4 epoch] loss: 0.045
# [    4 epoch] loss: 0.054
# [    4 epoch] loss: 0.050
# [    4 epoch] loss: 0.048
# [    4 epoch] loss: 0.051
# [    4 epoch] loss: 0.051
# [    4 epoch] loss: 0.042
# [    4 epoch] loss: 0.049
# [    5 epoch] loss: 0.071
# [    5 epoch] loss: 0.047
# [    5 epoch] loss: 0.055
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.045
# [    5 epoch] loss: 0.054
# [    5 epoch] loss: 0.048
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.046
# [    5 epoch] loss: 0.054
# [    5 epoch] loss: 0.051
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.043
# [    5 epoch] loss: 0.043
# [    5 epoch] loss: 0.049
# [    5 epoch] loss: 0.047
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.044
# [    5 epoch] loss: 0.053
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.047
# [    5 epoch] loss: 0.050
# [    5 epoch] loss: 0.051
# [    5 epoch] loss: 0.042
# [    5 epoch] loss: 0.049
# [    6 epoch] loss: 0.070
# [    6 epoch] loss: 0.047
# [    6 epoch] loss: 0.054
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.044
# [    6 epoch] loss: 0.054
# [    6 epoch] loss: 0.048
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.045
# [    6 epoch] loss: 0.054
# [    6 epoch] loss: 0.051
# [    6 epoch] loss: 0.050
# [    6 epoch] loss: 0.042
# [    6 epoch] loss: 0.042
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.046
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.044
# [    6 epoch] loss: 0.053
# [    6 epoch] loss: 0.049
# [    6 epoch] loss: 0.047
# [    6 epoch] loss: 0.050
# [    6 epoch] loss: 0.050
# [    6 epoch] loss: 0.041
# [    6 epoch] loss: 0.048
# [    7 epoch] loss: 0.069
# [    7 epoch] loss: 0.046
# [    7 epoch] loss: 0.054
# [    7 epoch] loss: 0.049
# [    7 epoch] loss: 0.044
# [    7 epoch] loss: 0.053
# [    7 epoch] loss: 0.047
# [    7 epoch] loss: 0.049
# [    7 epoch] loss: 0.045
# [    7 epoch] loss: 0.053
# [    7 epoch] loss: 0.050
# [    7 epoch] loss: 0.050
# [    7 epoch] loss: 0.042
# [    7 epoch] loss: 0.042
# [    7 epoch] loss: 0.048
# [    7 epoch] loss: 0.046
# [    7 epoch] loss: 0.049
# [    7 epoch] loss: 0.043
# [    7 epoch] loss: 0.053
# [    7 epoch] loss: 0.049
# [    7 epoch] loss: 0.047
# [    7 epoch] loss: 0.050
# [    7 epoch] loss: 0.050
# [    7 epoch] loss: 0.041
# [    7 epoch] loss: 0.048

# %%
torch.save(fullnet1.state_dict(), PATH)
import os 
import random     
from PIL import Image
fullnet2 = full_layers(True).to(device)
fullnet2.load_state_dict(torch.load(PATH))
dir_root = '/content/drive/MyDrive/Colab Notebooks/'    
train_dir = os.path.join(dir_root, 'train (1)') 
TRAIN_TRANSFORMS_reverse = transforms.Compose([transforms.ToPILImage()])
plt.figure(figsize=(30,30))
fullnet1.eval()
for i in range(1):
  file = random.choice(os.listdir(train_dir))
  image_path= os.path.join(train_dir, file)
  image= load_image(image_path)
  image_tensor = TRAIN_TRANSFORMS_256(image)
  inputs = image_tensor.unsqueeze(0)
  inputs = Variable(inputs.to(device))
  output = fullnet1(inputs,True)[0]
  map = fullnet1(inputs,True)[1]
  ax=plt.subplot(1,5,i+1)
  ax.title.set_text(file)
  plt.imshow(TRAIN_TRANSFORMS_reverse(image_tensor.squeeze_(0)))
  ax=plt.subplot(1,5,i+2)
  ax.title.set_text("importance map")
  #print(activation['imp_map'].shape,output.shape)
  plt.imshow(TRAIN_TRANSFORMS_reverse(map.squeeze_(0)))
  ax=plt.subplot(1,5,i+3)
  ax.title.set_text("compressed image")
  plt.imshow(TRAIN_TRANSFORMS_reverse(output.squeeze_(0)))
  print(map)
  #print(output[0])
# Out:
# tensor([[[0.4836, 0.4863, 0.4931,  ..., 0.4631, 0.4673, 0.4998],
#          [0.5044, 0.4254, 0.5449,  ..., 0.5643, 0.4773, 0.5618],
#          [0.5550, 0.5455, 0.6496,  ..., 0.5804, 0.5842, 0.5758],
#          ...,
#          [0.5180, 0.5093, 0.6520,  ..., 0.6263, 0.6212, 0.5692],
#          [0.5454, 0.5310, 0.7058,  ..., 0.5849, 0.5902, 0.6125],
#          [0.5762, 0.5246, 0.6147,  ..., 0.5590, 0.5627, 0.5001]]],
#        device='cuda:0')

# %%
# !pip install torchac
import torchac
